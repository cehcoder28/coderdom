# %% [markdown]
# <a href="https://colab.research.google.com/github/cehcoder28/coderdom/blob/master/MidExercise2(Lagata).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Task  1.  First,  Load  the  dataset  into  a  dataframe  named  df  and  describe  the  approach  you  used  to accomplish this task below:

# %%
url = 'https://raw.githubusercontent.com/cehcoder28/coderdom/master/autodata.csv' # In this program I get the url of the csv file name autodata then I use read_csv function to read the url that I get and to import and display the  datasets in a dataframe.
df = pd.read_csv(url)
df
# Out:
#     Index      Company   Body Style  ...  horsepower  AverageMileage    Price
# 0       0  alfa-romero  convertible  ...       111.0              21  13495.0
# 1       1  alfa-romero  convertible  ...       111.0              21  16500.0
# 2       2  alfa-romero    hatchback  ...       154.0              19  16500.0
# 3       3         audi        sedan  ...       102.0              24  13950.0
# 4       4         audi        sedan  ...       115.0              18  17450.0
# ..    ...          ...          ...  ...         ...             ...      ...
# 56     81   volkswagen        sedan  ...        85.0              27   7975.0
# 57     82   volkswagen        sedan  ...        52.0              37   7995.0
# 58     86   volkswagen        sedan  ...       100.0              26   9995.0
# 59     87        volvo        sedan  ...       114.0              23  12940.0
# 60     88        volvo        wagon  ...       114.0              23  13415.0
#
# [61 rows x 10 columns]

# %% [markdown]
# Task 2. Now we need to check that we have loaded the right dataset by inspecting the contents of the dataframe. Use the head, tail, info, index, and values functions to accomplish this task. Describe below what you’ve verified regarding the dataset based on the output of these commands:

# %%
df.tail(2) #I use the tail function to start the count of the value from last to the first example I want to display the last and the second to the last raws and columns
# Out:
#     index company body style  ...  horsepower  averagemileage    price
# 59     87   volvo      sedan  ...       114.0              23  12940.0
# 60     88   volvo      wagon  ...       114.0              23  13415.0
#
# [2 rows x 10 columns]

# %%
df.head(27) # I use the head function to display all the rows and columns and starts the count from the index.
# Out:
#     index      company   body style  ...  horsepower  averagemileage    price
# 0       0  alfa-romero  convertible  ...       111.0              21  13495.0
# 1       1  alfa-romero  convertible  ...       111.0              21  16500.0
# 2       2  alfa-romero    hatchback  ...       154.0              19  16500.0
# 3       3         audi        sedan  ...       102.0              24  13950.0
# 4       4         audi        sedan  ...       115.0              18  17450.0
# 5       5         audi        sedan  ...       110.0              19  15250.0
# 6       6         audi        wagon  ...       110.0              19  18920.0
# 7       9          bmw        sedan  ...       101.0              23  16430.0
# 8      10          bmw        sedan  ...       101.0              23  16925.0
# 9      11          bmw        sedan  ...         NaN              21  20970.0
# 10     13          bmw        sedan  ...       182.0              16  30760.0
# ...

# %%
df.info() #I use the info function to display all the information of the datasets like the total of columns and so on ans so for.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
# Index             61 non-null int64
# Company           61 non-null object
# Body Style        61 non-null object
# Wheel Base        61 non-null float64
# length            61 non-null float64
# Engine Type       58 non-null object
# # of Cylinders    61 non-null object
# horsepower        59 non-null float64
# AverageMileage    61 non-null int64
# Price             58 non-null float64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 4.9+ KB

# %%
df.values # The values function is use to display all the raws and columns of the data sets and split all the data using the comma.
# Out:
# array([[0, 'alfa-romero', 'convertible', 88.6, 168.8, 'dohc', 'four',
#         111.0, 21, 13495.0],
#        [1, 'alfa-romero', 'convertible', 88.6, 168.8, 'dohc', 'four',
#         111.0, 21, 16500.0],
#        [2, 'alfa-romero', 'hatchback', 94.5, 171.2, 'ohcv', 'six', 154.0,
#         19, 16500.0],
#        [3, 'audi', 'sedan', 99.8, 176.6, 'ohc', 'four', 102.0, 24,
#         13950.0],
#        [4, 'audi', 'sedan', 99.4, 176.6, 'ohc', 'five', 115.0, 18,
#         17450.0],
#        [5, 'audi', 'sedan', 99.8, 177.3, 'ohc', 'five', 110.0, 19,
#         15250.0],
#        [6, 'audi', 'wagon', 105.8, 192.7, 'ohc', 'five', 110.0, 19,
#         18920.0],
#        [9, 'bmw', 'sedan', 101.2, 176.8, 'ohc', 'four', 101.0, 23,
#         16430.0],
#        [10, 'bmw', 'sedan', 101.2, 176.8, 'ohc', 'four', 101.0, 23,
#         16925.0],
#        [11, 'bmw', 'sedan', 101.2, 176.8, 'ohc', 'six', nan, 21, 20970.0],
#        [13, 'bmw', 'sedan', 103.5, 189.0, 'ohc', 'six', 182.0, 16,
# ...

# %% [markdown]
# Task  3.  Inspect  the  datatype  of  each  attribute  in  the  dataset.  Provide  a  snapshot  of  the  command  and output  you used to accomplish this task in the space provided below. Some of the attributes will be marked as object, why do you think this is so? Provide your explanation on the space provided.

# %%
df.dtypes # the dtypes is use to display the datatypes of all the data example the what is the datatype of the index,company etc.
# Out:
# Index               int64
# Company            object
# Body Style         object
# Wheel Base        float64
# length            float64
# Engine Type        object
# # of Cylinders     object
# horsepower        float64
# AverageMileage      int64
# Price             float64
# dtype: object

# %% [markdown]
# Task 4. You need to tidy up the dataset first by converting the header names to proper form. Execute the task  that  will  enable  you  to  do  this.  Make  sure  that  all  names  are  in  lowercase  and  that  there  are  no embedded spaces and special characters. Provide a snapshot of the function you used to accomplish this task. How many column names needed adjustments?

# %%
df.columns = map(str.lower, df.columns)# The columns function is use basically to display the columns of the data but as you can see I use the map to find all and to  I also use the str to get all the strings of the data name of the header
                                      # and turn it to a lowercase using the lower function.
df
# Out:
#     index      company   body style  ...  horsepower  averagemileage    price
# 0       0  alfa-romero  convertible  ...       111.0              21  13495.0
# 1       1  alfa-romero  convertible  ...       111.0              21  16500.0
# 2       2  alfa-romero    hatchback  ...       154.0              19  16500.0
# 3       3         audi        sedan  ...       102.0              24  13950.0
# 4       4         audi        sedan  ...       115.0              18  17450.0
# ..    ...          ...          ...  ...         ...             ...      ...
# 56     81   volkswagen        sedan  ...        85.0              27   7975.0
# 57     82   volkswagen        sedan  ...        52.0              37   7995.0
# 58     86   volkswagen        sedan  ...       100.0              26   9995.0
# 59     87        volvo        sedan  ...       114.0              23  12940.0
# 60     88        volvo        wagon  ...       114.0              23  13415.0
#
# [61 rows x 10 columns]

# %% [markdown]
# Task 5. Now display all the records of vehicles manufactured by Isuzu. Provide a snapshot of the command and output you used to accomplish this task in the space provided below. Inspect the data in the price column. Based on your observation, what can you deduce about the state of the dataset?

# %%
df.loc[df['company'] == 'isuzu'] # In this  program as you can  it has  a loc function to find the condition inside of that so in this situation I want to find the name company rows but I want the isuzu data only thats why I 
                                  # Make a condition that if the company rows is equal to isuzu it will display.
# Out:
#     index company body style  ...  horsepower  averagemileage   price
# 21     30   isuzu      sedan  ...        78.0              24  6785.0
# 22     31   isuzu      sedan  ...        70.0              38     NaN
# 23     32   isuzu      sedan  ...        70.0              38     NaN
#
# [3 rows x 10 columns]

# %% [markdown]
# Task 6. Some of the columns in the dataset appear to have null values. You need to determine to what extent  this  problem  occurs  in  the  entire  dataset.  Execute  the  tasks  that  will  enable  you  to determine how many null values there are and post a snapshot of the command and output in the space provided. Then answer the questions: How many null values are in the dataset? How many columns have null values?

# %%
df.isnull().sum() # so the isnull function is to display all the  null values turn to True but I want to know how many null are in the data that's why I use the sum to add all the null values and display where is the null value.
# Out:
# index             0
# company           0
# body style        0
# wheel base        0
# length            0
# engine type       3
# # of cylinders    0
# horsepower        2
# averagemileage    0
# price             3
# dtype: int64

# %% [markdown]
# Task  7.  Delete  all  rows  with  null  Engine  type  values.  Post  a  snapshot  of  the  function  and  output  in  the space provided. Provide as much description as you can on how the function you used worked below:

# %%
df.dropna() # In this program I use the  dropna function to delete all the row values that has a null so as you analyze the data below you see that the rows that have a null are being remove like the number 22,23.
# Out:
#     index        company   body style  ...  horsepower  averagemileage    price
# 0       0    alfa-romero  convertible  ...       111.0              21  13495.0
# 1       1    alfa-romero  convertible  ...       111.0              21  16500.0
# 2       2    alfa-romero    hatchback  ...       154.0              19  16500.0
# 3       3           audi        sedan  ...       102.0              24  13950.0
# 4       4           audi        sedan  ...       115.0              18  17450.0
# 5       5           audi        sedan  ...       110.0              19  15250.0
# 6       6           audi        wagon  ...       110.0              19  18920.0
# 7       9            bmw        sedan  ...       101.0              23  16430.0
# 8      10            bmw        sedan  ...       101.0              23  16925.0
# 10     13            bmw        sedan  ...       182.0              16  30760.0
# 11     14            bmw        sedan  ...       182.0              16  41315.0
# ...

# %% [markdown]
# Task 8. Now perform imputation on the remaining numeric null values. Post a snapshot of the function and output in the space provided. Provide as much description as you can on how the function you used worked below:

# %%
name = df['price'] # So in this sitution as you can see I display all the mean of the values of price in the datasets using the imputation .
total_price = name.mean()
name.fillna(total_price,inplace=True)
print(name)
# Out:
# 0     13495.0
# 1     16500.0
# 2     16500.0
# 3     13950.0
# 4     17450.0
#        ...
# 56     7975.0
# 57     7995.0
# 58     9995.0
# 59    12940.0
# 60    13415.0
# Name: price, Length: 61, dtype: float64

# %% [markdown]
# Task 9. Delete the index column. Use the drop command for this task and make sure that inplace is set to true. Post a snapshot of the command and output you used to accomplish this task below. Describe the effect of setting inplace to true as compared to setting it to false.

# %%
a = df.loc[df['index']] # In this program I forget to answer this thats why I leave it blank
b = a.dropna()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.

# %% [markdown]
#  Task 10. Now, determine whether there are duplicate records in the dataset and if there are, delete all of them. How may duplicate records were there? Post a snapshot of the command and output you used to accomplish this task below:

# %%
df = df.drop_duplicates() # In this codes I delete all the duplicates values using the drop duplicates function.
df
# Out:
#     index        company   body style  ...  horsepower  averagemileage    price
# 2       2    alfa-romero    hatchback  ...       154.0              19  16500.0
# 3       3           audi        sedan  ...       102.0              24  13950.0
# 4       4           audi        sedan  ...       115.0              18  17450.0
# 5       5           audi        sedan  ...       110.0              19  15250.0
# 6       6           audi        wagon  ...       110.0              19  18920.0
# 7       9            bmw        sedan  ...       101.0              23  16430.0
# 8      10            bmw        sedan  ...       101.0              23  16925.0
# 9      11            bmw        sedan  ...         NaN              21  20970.0
# 10     13            bmw        sedan  ...       182.0              16  30760.0
# 11     14            bmw        sedan  ...       182.0              16  41315.0
# 12     15            bmw        sedan  ...       182.0              15  36880.0
# ...

# %% [markdown]
# Task 11. Use the scatter function of the dataframe to plot the Price and Horsepower column. Place price on the horizontal axis. Based on the chart, describe the relationship that you deem exists between these two variables. Post a snapshot of the command and output you used to accomplish this task below:

# %%
df.plot.scatter(x = 'price',y = 'horsepower') # In this char this is an examples of a strong correlation why? because if the value of price are became higher then  the horsepower are became higher too.

# %% [markdown]
# Task 12. Finally, use the corr() function to verify what you have observed in the previous task. Describe how you can use the output of this function to accomplish this task.

# %%
df.corr() # So in this program in describe all the correlation values of all data.
# Out:
#                    index  wheel base  ...  averagemileage     price
# index           1.000000   -0.073547  ...        0.151299 -0.207060
# wheel base     -0.073547    1.000000  ...       -0.604191  0.683718
# length         -0.012526    0.898715  ...       -0.800792  0.768737
# horsepower     -0.094795    0.478672  ...       -0.812281  0.801554
# averagemileage  0.151299   -0.604191  ...        1.000000 -0.737880
# price          -0.207060    0.683718  ...       -0.737880  1.000000
#
# [6 rows x 6 columns]

# %% [markdown]
# In your own words, write a summary of no less than 250 words of the new things that you have learned in this exercise. Save your notebook as MidExercise 2 (your_name) and submit in the designated folder in Canvas.
#
# In this exercise first of all my brain hearts me to think all the answer in this exercise.I learn firt how to analyze the data if I use a function then I to analyze that there's a lot of  function to be use to display or identify what you need to indentify. I also learn to research deeper than before to answer all the exercises. I also learn new thins like how to display a chart using a colab to identify the correlation of 2 values. In this exercise I learn how to be more confident to know what is the deeper answer to other exercise.  I learned how to other built in function that you did not discuss already sir. Thank you sir for exercises that gaves me a motivation to study more deeper and harder than before because I learn that if  I would not study hard my skills will  no be improve. Specially to think faster and to analyze deeper and deeeper. And in this program I learn to do a notes always when you discussed our lesson sir. Thank you sir for  this  exercises that I also learn how powerfull the python is specially in a big data  how to  clean all of the data that you give  , and to analyze and to explain it more suffiecient than before and to explain the big data using a correlation.I also appreciate sir how good teacher you are to give an hard exercise like this for us to think, analyze and to understand it.
